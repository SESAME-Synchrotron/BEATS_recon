# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.dpi'] = 150

# %%
slice200 = np.load("/home/gianthk/Data/StefanFly_test/test_00_/recon/slice200.npy")

# %%
plt.imshow(slice200, cmap='gray')
plt.show()
